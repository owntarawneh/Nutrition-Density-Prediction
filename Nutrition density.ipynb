# %% [markdown]
# # Preprocessing

# %%
import pandas as pd
import numpy as np

# %%
df1 = pd.read_csv('/content/FOOD-DATA-GROUP1.csv')
df1.shape
# Out:
# (551, 37)

# %%
df1.columns
# Out:
# Index(['Unnamed: 0.1', 'Unnamed: 0', 'food', 'Caloric Value', 'Fat',
#        'Saturated Fats', 'Monounsaturated Fats', 'Polyunsaturated Fats',
#        'Carbohydrates', 'Sugars', 'Protein', 'Dietary Fiber', 'Cholesterol',
#        'Sodium', 'Water', 'Vitamin A', 'Vitamin B1', 'Vitamin B11',
#        'Vitamin B12', 'Vitamin B2', 'Vitamin B3', 'Vitamin B5', 'Vitamin B6',
#        'Vitamin C', 'Vitamin D', 'Vitamin E', 'Vitamin K', 'Calcium', 'Copper',
#        'Iron', 'Magnesium', 'Manganese', 'Phosphorus', 'Potassium', 'Selenium',
#        'Zinc', 'Nutrition Density'],
#       dtype='object')

# %%
df1.head()
# Out:
#    Unnamed: 0.1  Unnamed: 0                              food  Caloric Value  \
# 0             0           0                      cream cheese             51
# 1             1           1                 neufchatel cheese            215
# 2             2           2  requeijao cremoso light catupiry             49
# 3             3           3                    ricotta cheese             30
# 4             4           4              cream cheese low fat             30
#
#     Fat  Saturated Fats  Monounsaturated Fats  Polyunsaturated Fats  \
# 0   5.0             2.9                   1.3                 0.200
# 1  19.4            10.9                   4.9                 0.800
# 2   3.6             2.3                   0.9                 0.000
# 3   2.0             1.3                   0.5                 0.002
# 4   2.3             1.4                   0.6                 0.042
#
#    Carbohydrates  Sugars  ...  Calcium  Copper   Iron  Magnesium  Manganese  \
# ...

# %%
df2 = pd.read_csv('/content/FOOD-DATA-GROUP2.csv')
df2.shape
# Out:
# (319, 37)

# %%
df3 = pd.read_csv('/content/FOOD-DATA-GROUP3.csv')
df3.shape
# Out:
# (571, 37)

# %%
df4 = pd.read_csv('/content/FOOD-DATA-GROUP4.csv')
df4.shape
# Out:
# (232, 37)

# %%
df5 = pd.read_csv('/content/FOOD-DATA-GROUP5.csv')
df5.shape
# Out:
# (722, 37)

# %% [markdown]
# I first wanted to make a prediction model on each file, but the numbers of samples are very samall so i will merge the excel files to get better results

# %%
# i need to merge all the files in one
df = pd.concat([df1,df2,df3,df4,df5])
df.shape
# Out:
# (2395, 37)

# %%
df.head()
# we can see from the meta data that the first two columns are just indexs
# Out:
#    Unnamed: 0.1  Unnamed: 0                              food  Caloric Value  \
# 0             0           0                      cream cheese             51
# 1             1           1                 neufchatel cheese            215
# 2             2           2  requeijao cremoso light catupiry             49
# 3             3           3                    ricotta cheese             30
# 4             4           4              cream cheese low fat             30
#
#     Fat  Saturated Fats  Monounsaturated Fats  Polyunsaturated Fats  \
# 0   5.0             2.9                   1.3                 0.200
# 1  19.4            10.9                   4.9                 0.800
# 2   3.6             2.3                   0.9                 0.000
# 3   2.0             1.3                   0.5                 0.002
# 4   2.3             1.4                   0.6                 0.042
#
#    Carbohydrates  Sugars  ...  Calcium  Copper   Iron  Magnesium  Manganese  \
# ...

# %%
df.isnull().sum()
# Out:
# Unnamed: 0.1            0
# Unnamed: 0              0
# food                    0
# Caloric Value           0
# Fat                     0
# Saturated Fats          0
# Monounsaturated Fats    0
# Polyunsaturated Fats    0
# Carbohydrates           0
# Sugars                  0
# Protein                 0
# Dietary Fiber           0
# Cholesterol             0
# Sodium                  0
# Water                   0
# Vitamin A               0
# Vitamin B1              0
# Vitamin B11             0
# Vitamin B12             0
# Vitamin B2              0
# Vitamin B3              0
# Vitamin B5              0
# Vitamin B6              0
# Vitamin C               0
# Vitamin D               0
# Vitamin E               0
# Vitamin K               0
# Calcium                 0
# Copper                  0
# Iron                    0
# Magnesium               0
# Manganese               0
# Phosphorus              0
# Potassium               0
# Selenium                0
# ...

# %%
# i will drop the first two columns
df = df.drop(columns=['Unnamed: 0','Unnamed: 0.1'])
df.head()
# Out:
#                                food  Caloric Value   Fat  Saturated Fats  \
# 0                      cream cheese             51   5.0             2.9
# 1                 neufchatel cheese            215  19.4            10.9
# 2  requeijao cremoso light catupiry             49   3.6             2.3
# 3                    ricotta cheese             30   2.0             1.3
# 4              cream cheese low fat             30   2.3             1.4
#
#    Monounsaturated Fats  Polyunsaturated Fats  Carbohydrates  Sugars  Protein  \
# 0                   1.3                 0.200            0.8   0.500      0.9
# 1                   4.9                 0.800            3.1   2.700      7.8
# 2                   0.9                 0.000            0.9   3.400      0.8
# 3                   0.5                 0.002            1.5   0.091      1.5
# 4                   0.6                 0.042            1.2   0.900      1.2
#
# ...

# %%
df.replace(0, np.nan, inplace=True)
df.dropna(inplace=True)

# %%
plt.figure(figsize=(8, 4))
sns.histplot(df['Nutrition Density'], bins=30, kde=True)
plt.title("Distribution of Nutrition Density")
plt.xlabel("Nutrition Density")
plt.grid(True)
plt.tight_layout()
plt.show()

# %% [markdown]
# # Linear Regression Without feature Eng

# %%
df = pd.get_dummies(df, columns=['food'])

# %%
X = df.drop(columns=['Nutrition Density'])
y = df['Nutrition Density']

# %%
import pandas as pd
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score, mean_squared_error, mean_absolute_error
import numpy as np

X_train, X_test, y_train, y_test = train_test_split(X_scaled, y, test_size=0.2, random_state=42)

# Train model
model = LinearRegression()
model.fit(X_train, y_train)

# Predict
y_pred = model.predict(X_test)

# Evaluate
print("R²:", r2_score(y_test, y_pred))
print("RMSE:", np.sqrt(mean_squared_error(y_test, y_pred)))
print("MAE:", mean_absolute_error(y_test, y_pred))
# Out:
# R²: 0.8489178574598899
# RMSE: 37.66179339402578
# MAE: 25.177037105280775

# %%
from sklearn.model_selection import KFold, cross_val_score

kfold = KFold(n_splits=5, shuffle=True, random_state=42)
cv_scores = cross_val_score(model, X_scaled, y, cv=kfold, scoring='r2')

print("K-Fold Cross-Validation R² scores:", cv_scores)
print("Average R²:", np.mean(cv_scores))
# Out:
# K-Fold Cross-Validation R² scores: [0.84891786 0.6418088  0.54760188 0.77895515 0.82455211]
# Average R²: 0.7283671619304768

# %%
import numpy as np
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score
import matplotlib.pyplot as plt

# Set how many random shuffles to perform
n_permutations = 100  # change to 500 or 100 for speed

# Your actual model score
real_r2 = r2_score(y_test, y_pred)

# Store permuted R² scores
r2_perm_scores = []
np.random.seed(42)  # reproducibility

for _ in range(n_permutations):
    y_train_perm = np.random.permutation(y_train)
    perm_model = LinearRegression().fit(X_train, y_train_perm)
    y_pred_perm = perm_model.predict(X_test)
    r2_perm_scores.append(r2_score(y_test, y_pred_perm))

# Calculate permutation p-value
count = np.sum(np.array(r2_perm_scores) >= real_r2)
p_value = count / n_permutations

# Print summary
print(f"Real R²: {real_r2:.4f}")
print(f"Mean R² (permuted): {np.mean(r2_perm_scores):.4f}")
print(f"P-value: {p_value:.4f} (proportion of permuted R² ≥ real R²)")

# Plot distribution
plt.hist(r2_perm_scores, bins=30, alpha=0.7, label='Permuted R²')
plt.axvline(real_r2, color='red', linestyle='dashed', linewidth=2, label='Real R²')
plt.title("Permutation Test: R² Distribution")
plt.xlabel("R² Score")
plt.ylabel("Frequency")
plt.legend()
plt.grid(True)
plt.show()
# Out:
# Real R²: 0.8489
# Mean R² (permuted): -2.5981
# P-value: 0.0000 (proportion of permuted R² ≥ real R²)

# %%
import matplotlib.pyplot as plt
plt.scatter(y_test, y_pred)
plt.xlabel("Actual")
plt.ylabel("Predicted")
plt.title("Nutrition Density: Actual vs Predicted")
plt.grid(True)
plt.show()

# %%
import seaborn as sns

residuals = y_test - y_pred
plt.figure(figsize=(8, 6))
sns.scatterplot(x=y_pred, y=residuals)
plt.axhline(0, color='red', linestyle='--')
plt.title("Residuals vs Predicted Nutrition Density")
plt.xlabel("Predicted")
plt.ylabel("Residual (Actual - Predicted)")
plt.grid(True)
plt.show()

# %%
plt.figure(figsize=(10, 4))
plt.plot(list(y_test.values[:50]), label='Actual')
plt.plot(list(y_pred[:50]), label='Predicted', linestyle='dashed')
plt.title("Actual vs Predicted (First 50 samples)")
plt.ylabel("Nutrition Density")
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()

# %% [markdown]
# #Linear Regression With Eng

# %%
pd.Series(model.coef_, index=df.drop(columns=['Nutrition Density']).columns).sort_values(ascending=False)
# Out:
# Calcium                                      49.834336
# food_pimento cheese                          47.173089
# Phosphorus                                   30.414290
# Saturated Fats                               28.580922
# Vitamin B2                                   21.804562
#                                                ...
# food_mashed potato with milk and butter      -7.383695
# food_eclair                                 -10.497332
# food_pasta with meatballs in tomato sauce   -11.146606
# food_biscuit with egg                       -11.546787
# food_general tsos chicken                   -25.051206
# Length: 71, dtype: float64

# %%
correlations = df.corr()['Nutrition Density'].sort_values(ascending=False)
print(correlations)
# Out:
# Nutrition Density       1.000000
# Calcium                 0.947079
# Vitamin B2              0.904675
# Saturated Fats          0.901076
# Phosphorus              0.900116
#                           ...
# food_chicken nuggets   -0.111207
# Vitamin K              -0.115601
# Selenium               -0.147612
# Manganese              -0.153768
# Vitamin B12            -0.154152
# Name: Nutrition Density, Length: 72, dtype: float64

# %%
top_features = df.corr()['Nutrition Density'].abs().sort_values(ascending=False).head(20).index
top_features
# Out:
# Index(['Nutrition Density', 'Calcium', 'Vitamin B2', 'Saturated Fats',
#        'Phosphorus', 'Magnesium', 'Monounsaturated Fats', 'Fat',
#        'Caloric Value', 'Vitamin B1', 'Carbohydrates', 'Potassium', 'Iron',
#        'food_banana cream pie', 'Cholesterol', 'Zinc', 'Sodium', 'Sugars',
#        'Water', 'Polyunsaturated Fats'],
#       dtype='object')

# %%
import seaborn as sns
import matplotlib.pyplot as plt

plt.figure(figsize=(12, 8))
sns.heatmap(df[top_features].corr(), annot=True, cmap='coolwarm')
plt.title("Top Feature Correlations with Nutrition Density")
plt.show()

# %%
df.corr()['Nutrition Density'].drop('Nutrition Density').sort_values().tail(20).plot(kind='barh', figsize=(10, 8))
plt.title("Top 20 Correlated Features with Nutrition Density")
plt.xlabel("Correlation Coefficient")
plt.grid(True)
plt.show()

# %%
top_features = [
    'Calcium', 'Vitamin B2', 'Saturated Fats', 'Phosphorus', 'Magnesium',
    'Monounsaturated Fats', 'Fat', 'Caloric Value', 'Vitamin B1', 'Carbohydrates',
    'Potassium', 'Iron', 'food_banana cream pie', 'Cholesterol', 'Zinc',
    'Sodium', 'Sugars', 'Water', 'Polyunsaturated Fats', 'Protein'
]

X = df[top_features]
y = df['Nutrition Density']

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.metrics import r2_score, mean_squared_error, mean_absolute_error

scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

X_train, X_test, y_train, y_test = train_test_split(X_scaled, y, test_size=0.2, random_state=42)

model = LinearRegression()
model.fit(X_train, y_train)
y_pred = model.predict(X_test)

# %%
print("R²:", r2_score(y_test, y_pred))
print("RMSE:", np.sqrt(mean_squared_error(y_test, y_pred)))
print("MAE:", mean_absolute_error(y_test, y_pred))
# Out:
# R²: 0.9949531721794425
# RMSE: 6.883410552252058
# MAE: 4.479702510611647

# %%
from sklearn.model_selection import KFold, cross_val_score

kfold = KFold(n_splits=5, shuffle=True, random_state=42)
cv_scores = cross_val_score(model, X_scaled, y, cv=kfold, scoring='r2')

print("K-Fold Cross-Validation R² scores:", cv_scores)
print("Average R²:", np.mean(cv_scores))
# Out:
# K-Fold Cross-Validation R² scores: [0.99495317 0.99178679 0.99811249 0.99750458 0.99910337]
# Average R²: 0.9962920796447433

# %%
import numpy as np
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score
import matplotlib.pyplot as plt

# Set how many random shuffles to perform
n_permutations = 100  # change to 500 or 100 for speed

# Your actual model score
real_r2 = r2_score(y_test, y_pred)

# Store permuted R² scores
r2_perm_scores = []
np.random.seed(42)  # reproducibility

for _ in range(n_permutations):
    y_train_perm = np.random.permutation(y_train)
    perm_model = LinearRegression().fit(X_train, y_train_perm)
    y_pred_perm = perm_model.predict(X_test)
    r2_perm_scores.append(r2_score(y_test, y_pred_perm))

# Calculate permutation p-value
count = np.sum(np.array(r2_perm_scores) >= real_r2)
p_value = count / n_permutations

# Print summary
print(f"Real R²: {real_r2:.4f}")
print(f"Mean R² (permuted): {np.mean(r2_perm_scores):.4f}")
print(f"P-value: {p_value:.4f} (proportion of permuted R² ≥ real R²)")

# Plot distribution
plt.hist(r2_perm_scores, bins=30, alpha=0.7, label='Permuted R²')
plt.axvline(real_r2, color='red', linestyle='dashed', linewidth=2, label='Real R²')
plt.title("Permutation Test: R² Distribution")
plt.xlabel("R² Score")
plt.ylabel("Frequency")
plt.legend()
plt.grid(True)
plt.show()
# Out:
# Real R²: 0.9950
# Mean R² (permuted): -25.7817
# P-value: 0.0000 (proportion of permuted R² ≥ real R²)

# %%
import seaborn as sns

residuals = y_test - y_pred
plt.figure(figsize=(8, 6))
sns.scatterplot(x=y_pred, y=residuals)
plt.axhline(0, color='red', linestyle='--')
plt.title("Residuals vs Predicted Nutrition Density")
plt.xlabel("Predicted")
plt.ylabel("Residual (Actual - Predicted)")
plt.grid(True)
plt.show()

# %%
plt.figure(figsize=(10, 4))
plt.plot(list(y_test.values[:50]), label='Actual')
plt.plot(list(y_pred[:50]), label='Predicted', linestyle='dashed')
plt.title("Actual vs Predicted (First 50 samples)")
plt.ylabel("Nutrition Density")
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()
